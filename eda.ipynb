# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv("dataset.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
# Indentifying the null values in case they could be useful
missing_artists = pd.isnull(data["artists"])
missing_artists_data = data[missing_artists]
missing_artists_data
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 65900           0            0     False         0.501   0.583  ...     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre
# 65900  138.391               4        k-pop
#
# [1 rows x 21 columns]

# %%
# Dropping the null values 
data = data.dropna()

# %%
# Checking the unique type of music genres
data["track_genre"].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
# ...

# %%
# Check the mean of each genre popularity
genre_popularity = data.groupby("track_genre")["popularity"].mean()
print(genre_popularity)
# Out:
# track_genre
# acoustic       42.483
# afrobeat       24.399
# alt-rock       33.943
# alternative    24.337
# ambient        44.191
#                 ...
# techno         39.042
# trance         37.635
# trip-hop       34.460
# turkish        40.698
# world-music    41.873
# Name: popularity, Length: 114, dtype: float64

# %%
top_genres = genre_popularity.nlargest(20).sort_values(ascending=True)
plt.figure(figsize=(12,6))
sns.barplot(top_genres,palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Genre")
plt.ylabel("Popularity 0-100")
plt.title("Top 20 Popular Genres")
plt.show()
# Out:
# /var/folders/n8/gx2myhcx3wz9n5lc8435j8d80000gn/T/ipykernel_31808/3776960580.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(top_genres,palette="viridis")

# %%
# Lowkey surprised hip hop aint here, I can see some correlations between amount of population and the mean popularity for example the indian and mandopop genre which correspond 
# to large countries like India and China respectively, moreover seeing kpop on top reflects its massive global audience and how trendy it is nowadays since the popularity metric in this dataset takes into
# consideration "recent" reproductions of the tracks.

# %%
# Check the mean of each genre danceability
genre_danceability = data.groupby("track_genre")["danceability"].mean()

# %%
most_danceable_genres = genre_danceability.nlargest(20).sort_values(ascending=True)
plt.figure(figsize=(12,6))
sns.barplot(most_danceable_genres,palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Genre")
plt.ylabel("Danceability 0-1")
plt.title("Top 20 Genres")
plt.show()
# Out:
# /var/folders/n8/gx2myhcx3wz9n5lc8435j8d80000gn/T/ipykernel_31808/157802678.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(most_danceable_genres,palette="viridis")

# %%
# Doing the same procedure in popularity and danceability we can appreaciate that the 20 most danceable genres by mean 
# are not the same as the top 20 most popular genres except by deep-house. An appreciation I would like to make is that study music
# is part of the 20 most danceable genres

# %%
# Danceability vs Popularity by song its messy af ngl
plt.figure(figsize=(12,6))
sns.scatterplot(x=data["danceability"],y=data["popularity"])
plt.title("Danceability vs Popularity")
plt.show()

# %%
genre_stats = data.groupby("track_genre")[["danceability", "popularity"]].mean()
plt.figure(figsize=(10,6))
sns.scatterplot(x=genre_stats["danceability"], y=genre_stats["popularity"])
plt.xlabel("Danceability mean")
plt.ylabel("Popularidad mean")
plt.title("Relationship between Danceability and Popularity by genre")
plt.show()

# %%
# Correlation matrix
correlation_matrix = data[["popularity", "danceability"]].corr()
print(correlation_matrix)
# Out:
#               popularity  danceability
# popularity      1.000000      0.035444
# danceability    0.035444      1.000000

# %%
# Correlation matrix by genre
genre_correlation = data.groupby("track_genre")[["popularity", "danceability"]].corr().unstack().iloc[:,1]
print(genre_correlation)
# Out:
# track_genre
# acoustic       0.050957
# afrobeat      -0.025081
# alt-rock       0.010425
# alternative   -0.005142
# ambient        0.038649
#                  ...
# techno         0.016804
# trance        -0.110488
# trip-hop      -0.013264
# turkish        0.017546
# world-music    0.196738
# Name: (popularity, danceability), Length: 114, dtype: float64
